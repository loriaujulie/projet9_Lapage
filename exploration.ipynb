# %% [markdown]
# ### Import des librairies utiles pour ce projet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# ### Chargement du dataset selon les csv remis lors de la mission

# %%
clients = pd.read_csv(r'..\P9_Lapage\data\raw\customers.csv')
produits = pd.read_csv(r'..\P9_Lapage\data\raw\products.csv')
transactions = pd.read_csv(r'..\P9_Lapage\data\raw\Transactions.csv')

# %% [markdown]
# ### Dimensionnement du dataset

# %%
clients.info()
