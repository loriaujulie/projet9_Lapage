# %% [markdown]
# ### Import des librairies utiles pour ce projet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import statsmodels.api as sm

# %% [markdown]
# ### Chargement du dataset selon les csv remis lors de la mission

# %%
df_lapage=pd.read_csv(r'..\..\projet9_Lapage\data\processed\df_lapage.csv',sep=';', encoding='utf-8')
# Out:
# C:\Users\julie\AppData\Local\Temp\ipykernel_39684\591950576.py:3: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   transactions = pd.read_csv(r'..\projet9_Lapage\data\raw\Transactions.csv',sep=';', encoding='utf-8')
